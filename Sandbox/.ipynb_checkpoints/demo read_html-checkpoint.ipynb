# %%
import pandas as pd

# %%
url = 'https://nl.wikipedia.org/wiki/Provincies_van_Nederland'

# %% [markdown]
# #### read_html returns a list of dataframes

# %%
pd.read_html(url)
# Out:
# [    Vlag            Provincie Bevolking[1] Oppervlakte(land+water) in km²  \
#  0    NaN            Groningen      585.866                       2.959,68
#  1    NaN  Friesland (Fryslân)      649.957                       5.748,77
#  2    NaN              Drenthe      493.682                       2.680,39
#  3    NaN           Overijssel    1.162.406                       3.420,74
#  4    NaN            Flevoland      423.021                       2.412,31
#  5    NaN           Gelderland    2.085.952                       5.136,31
#  6    NaN              Utrecht    1.354.834                       1.560,05
#  7    NaN        Noord-Holland    2.879.527                       4.091,93
#  8    NaN         Zuid-Holland    3.708.696                       3.307,86
#  9    NaN              Zeeland      383.488                       2.933,44
#  10   NaN        Noord-Brabant    2.562.955                       5.082,06
#  11   NaN              Limburg    1.117.201                       2.209,85
#
#     Oppervlakte(land) in km²  inw./km²[2]         Hoofdstad  \
#  0                  2.323,94      252.000         Groningen
#  1                  3.335,62      195.000        Leeuwarden
#  2                  2.632,65      188.000             Assen
#  3                  3.319,00      350.000            Zwolle
#  4                  1.411,63      300.000          Lelystad
#  5                  4.963,71      420.000            Arnhem
#  6                  1.485,46      912.000           Utrecht
#  7                  2.664,82        1.081           Haarlem
#  8                  2.700,07        1.374          Den Haag
#  9                  1.782,12      215.000        Middelburg
#  10                 4.905,46      522.000  's-Hertogenbosch
#  11                 2.146,61      520.000        Maastricht
#
#     Gemeente met demeeste inwoners
#  0                       Groningen
#  1                      Leeuwarden
#  2                           Emmen
#  3                        Enschede
#  4                          Almere
#  5                        Nijmegen
#  6                         Utrecht
#  7                       Amsterdam
#  8                       Rotterdam
#  9                       Terneuzen
#  10                      Eindhoven
#  11                     Maastricht  ,
#                                                     0
#  0                               Nederlandse politiek
#  1        Statuut voor het Koninkrijk der Nederlanden
#  2                               Nederlandse Grondwet
#  3  Nederlandse regering Staatshoofd Willem-Alexan...
#  4  Hoge Colleges van Staat Eerste Kamer historisc...
#  5                          Hoge Raad der Nederlanden
#  6  Decentrale overheden Provincies Provinciale St...
#  7                  Portaal PolitiekPortaal Nederland,
#                                                     0
#  0  Bronnen, noten en/of referenties Vanaf paragra...,
#                                                     0  \
#  0                           Provincies van Nederland
#  1  Drenthe · Flevoland · Friesland · Gelderland ·...
#
#                                                     1
#  0                                                NaN
#  1  Drenthe · Flevoland · Friesland · Gelderland ·...  ]

# %% [markdown]
# #### Get the first dataframe

# %%
df = pd.read_html(url, thousands = '.', decimal = ',')[0]
df
# Out:
#     Vlag            Provincie  Bevolking[1]  Oppervlakte(land+water) in km²  \
# 0    NaN            Groningen        585866                         2959.68
# 1    NaN  Friesland (Fryslân)        649957                         5748.77
# 2    NaN              Drenthe        493682                         2680.39
# 3    NaN           Overijssel       1162406                         3420.74
# 4    NaN            Flevoland        423021                         2412.31
# 5    NaN           Gelderland       2085952                         5136.31
# 6    NaN              Utrecht       1354834                         1560.05
# 7    NaN        Noord-Holland       2879527                         4091.93
# 8    NaN         Zuid-Holland       3708696                         3307.86
# 9    NaN              Zeeland        383488                         2933.44
# 10   NaN        Noord-Brabant       2562955                         5082.06
# 11   NaN              Limburg       1117201                         2209.85
#
#     Oppervlakte(land) in km²  inw./km²[2]         Hoofdstad  \
# 0                    2323.94          252         Groningen
# 1                    3335.62          195        Leeuwarden
# 2                    2632.65          188             Assen
# 3                    3319.00          350            Zwolle
# 4                    1411.63          300          Lelystad
# 5                    4963.71          420            Arnhem
# 6                    1485.46          912           Utrecht
# 7                    2664.82         1081           Haarlem
# 8                    2700.07         1374          Den Haag
# 9                    1782.12          215        Middelburg
# 10                   4905.46          522  's-Hertogenbosch
# 11                   2146.61          520        Maastricht
#
#    Gemeente met demeeste inwoners
# 0                       Groningen
# 1                      Leeuwarden
# 2                           Emmen
# 3                        Enschede
# 4                          Almere
# 5                        Nijmegen
# 6                         Utrecht
# 7                       Amsterdam
# 8                       Rotterdam
# 9                       Terneuzen
# 10                      Eindhoven
# 11                     Maastricht

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Vlag                            0 non-null      float64
#  1   Provincie                       12 non-null     object
#  2   Bevolking                       12 non-null     int64
#  3   Oppervlakte                     12 non-null     float64
#  4   Oppervlakte Land                12 non-null     float64
#  5   inwonersdichtheid               12 non-null     int64
#  6   Hoofdstad                       12 non-null     object
#  7   Gemeente met demeeste inwoners  12 non-null     object
# dtypes: float64(3), int64(2), object(3)
# memory usage: 896.0+ bytes

# %%
df
# Out:
#     Vlag            Provincie  Bevolking[1]  Oppervlakte(land+water) in km²  \
# 0    NaN            Groningen        585866                         2959.68
# 1    NaN  Friesland (Fryslân)        649957                         5748.77
# 2    NaN              Drenthe        493682                         2680.39
# 3    NaN           Overijssel       1162406                         3420.74
# 4    NaN            Flevoland        423021                         2412.31
# 5    NaN           Gelderland       2085952                         5136.31
# 6    NaN              Utrecht       1354834                         1560.05
# 7    NaN        Noord-Holland       2879527                         4091.93
# 8    NaN         Zuid-Holland       3708696                         3307.86
# 9    NaN              Zeeland        383488                         2933.44
# 10   NaN        Noord-Brabant       2562955                         5082.06
# 11   NaN              Limburg       1117201                         2209.85
#
#     Oppervlakte(land) in km²  inw./km²[2]         Hoofdstad  \
# 0                    2323.94          252         Groningen
# 1                    3335.62          195        Leeuwarden
# 2                    2632.65          188             Assen
# 3                    3319.00          350            Zwolle
# 4                    1411.63          300          Lelystad
# 5                    4963.71          420            Arnhem
# 6                    1485.46          912           Utrecht
# 7                    2664.82         1081           Haarlem
# 8                    2700.07         1374          Den Haag
# 9                    1782.12          215        Middelburg
# 10                   4905.46          522  's-Hertogenbosch
# 11                   2146.61          520        Maastricht
#
#    Gemeente met demeeste inwoners
# 0                       Groningen
# 1                      Leeuwarden
# 2                           Emmen
# 3                        Enschede
# 4                          Almere
# 5                        Nijmegen
# 6                         Utrecht
# 7                       Amsterdam
# 8                       Rotterdam
# 9                       Terneuzen
# 10                      Eindhoven
# 11                     Maastricht

# %%
df.rename(columns = {'Bevolking[1]': 'Bevolking', 
                     'Oppervlakte(land+water) in km²':'Oppervlakte',
                     'Oppervlakte(land) in km²':'Oppervlakte Land',
                     'inw./km²[2]':'inwonersdichtheid'}, 
          inplace = True)

# %%
df
# Out:
#     Vlag            Provincie  Bevolking  Oppervlakte  Oppervlakte Land  \
# 0    NaN            Groningen     585866      2959.68           2323.94
# 1    NaN  Friesland (Fryslân)     649957      5748.77           3335.62
# 2    NaN              Drenthe     493682      2680.39           2632.65
# 3    NaN           Overijssel    1162406      3420.74           3319.00
# 4    NaN            Flevoland     423021      2412.31           1411.63
# 5    NaN           Gelderland    2085952      5136.31           4963.71
# 6    NaN              Utrecht    1354834      1560.05           1485.46
# 7    NaN        Noord-Holland    2879527      4091.93           2664.82
# 8    NaN         Zuid-Holland    3708696      3307.86           2700.07
# 9    NaN              Zeeland     383488      2933.44           1782.12
# 10   NaN        Noord-Brabant    2562955      5082.06           4905.46
# 11   NaN              Limburg    1117201      2209.85           2146.61
#
#     inwonersdichtheid         Hoofdstad Gemeente met demeeste inwoners
# 0                 252         Groningen                      Groningen
# 1                 195        Leeuwarden                     Leeuwarden
# 2                 188             Assen                          Emmen
# 3                 350            Zwolle                       Enschede
# 4                 300          Lelystad                         Almere
# 5                 420            Arnhem                       Nijmegen
# 6                 912           Utrecht                        Utrecht
# 7                1081           Haarlem                      Amsterdam
# 8                1374          Den Haag                      Rotterdam
# 9                 215        Middelburg                      Terneuzen
# 10                522  's-Hertogenbosch                      Eindhoven
# 11                520        Maastricht                     Maastricht

# %%
df['Provincie'] = df['Provincie'].astype('string')
df['Hoofdstad'] = df['Hoofdstad'].astype('string')
df['Gemeente met demeeste inwoners'] = df['Gemeente met demeeste inwoners'].astype('string')

# %%
df.dtypes
# Out:
# Vlag                              float64
# Provincie                          string
# Bevolking[1]                        int64
# Oppervlakte(land+water) in km²    float64
# Oppervlakte(land) in km²          float64
# inw./km²[2]                         int64
# Hoofdstad                          string
# Gemeente met demeeste inwoners     string
# dtype: object

# %%
df[['Provincie','Hoofdstad']]
# Out:
#               Provincie         Hoofdstad
# 0             Groningen         Groningen
# 1   Friesland (Fryslân)        Leeuwarden
# 2               Drenthe             Assen
# 3            Overijssel            Zwolle
# 4             Flevoland          Lelystad
# 5            Gelderland            Arnhem
# 6               Utrecht           Utrecht
# 7         Noord-Holland           Haarlem
# 8          Zuid-Holland          Den Haag
# 9               Zeeland        Middelburg
# 10        Noord-Brabant  's-Hertogenbosch
# 11              Limburg        Maastricht

# %%
df['Bevolking']
# Out:
# 0      585866
# 1      649957
# 2      493682
# 3     1162406
# 4      423021
# 5     2085952
# 6     1354834
# 7     2879527
# 8     3708696
# 9      383488
# 10    2562955
# 11    1117201
# Name: Bevolking, dtype: int64

# %%
import locale
locale.setlocale(locale.LC_ALL, '')
# Out:
# 'nl_NL.UTF-8'

# %%
aantal_nederlanders = df['Bevolking'].sum()
print(f'Er wonen {aantal_nederlanders} mensen in Nederland')
# Out:
# Er wonen 17407585 mensen in Nederland

# %%
totale_land_oppervlakte = df['Oppervlakte Land'].sum()

# %%
print(f'Totale landoppervlakte is {totale_land_oppervlakte} km²')
# Out:
# Totale landoppervlakte is 33671.09 km²

# %% [markdown]
# ### Filteren op Provincies met inwonersdichtheid > 500

# %%
df[df['inwonersdichtheid'] > 500]
# Out:
#     Vlag      Provincie  Bevolking  Oppervlakte  Oppervlakte Land  \
# 6    NaN        Utrecht    1354834      1560.05           1485.46
# 7    NaN  Noord-Holland    2879527      4091.93           2664.82
# 8    NaN   Zuid-Holland    3708696      3307.86           2700.07
# 10   NaN  Noord-Brabant    2562955      5082.06           4905.46
# 11   NaN        Limburg    1117201      2209.85           2146.61
#
#     inwonersdichtheid         Hoofdstad Gemeente met demeeste inwoners
# 6                 912           Utrecht                        Utrecht
# 7                1081           Haarlem                      Amsterdam
# 8                1374          Den Haag                      Rotterdam
# 10                522  's-Hertogenbosch                      Eindhoven
# 11                520        Maastricht                     Maastricht

# %%
df.loc[df['inwonersdichtheid'] > 500, ['Provincie','Hoofdstad']]
# Out:
#         Provincie         Hoofdstad
# 6         Utrecht           Utrecht
# 7   Noord-Holland           Haarlem
# 8    Zuid-Holland          Den Haag
# 10  Noord-Brabant  's-Hertogenbosch
# 11        Limburg        Maastricht

# %%
df.loc[df['inwonersdichtheid'] > 500, ['Hoofdstad','Provincie']]
# Out:
#            Hoofdstad      Provincie
# 6            Utrecht        Utrecht
# 7            Haarlem  Noord-Holland
# 8           Den Haag   Zuid-Holland
# 10  's-Hertogenbosch  Noord-Brabant
# 11        Maastricht        Limburg

# %%
df['berekende dichtheid'] = (df['Bevolking'] / df['Oppervlakte Land']).round().astype('int')

# %%
df
# Out:
#     Vlag            Provincie  Bevolking  Oppervlakte  Oppervlakte Land  \
# 0    NaN            Groningen     585866      2959.68           2323.94
# 1    NaN  Friesland (Fryslân)     649957      5748.77           3335.62
# 2    NaN              Drenthe     493682      2680.39           2632.65
# 3    NaN           Overijssel    1162406      3420.74           3319.00
# 4    NaN            Flevoland     423021      2412.31           1411.63
# 5    NaN           Gelderland    2085952      5136.31           4963.71
# 6    NaN              Utrecht    1354834      1560.05           1485.46
# 7    NaN        Noord-Holland    2879527      4091.93           2664.82
# 8    NaN         Zuid-Holland    3708696      3307.86           2700.07
# 9    NaN              Zeeland     383488      2933.44           1782.12
# 10   NaN        Noord-Brabant    2562955      5082.06           4905.46
# 11   NaN              Limburg    1117201      2209.85           2146.61
#
#     inwonersdichtheid         Hoofdstad Gemeente met demeeste inwoners  \
# 0                 252         Groningen                      Groningen
# 1                 195        Leeuwarden                     Leeuwarden
# 2                 188             Assen                          Emmen
# 3                 350            Zwolle                       Enschede
# 4                 300          Lelystad                         Almere
# 5                 420            Arnhem                       Nijmegen
# 6                 912           Utrecht                        Utrecht
# 7                1081           Haarlem                      Amsterdam
# 8                1374          Den Haag                      Rotterdam
# 9                 215        Middelburg                      Terneuzen
# 10                522  's-Hertogenbosch                      Eindhoven
# 11                520        Maastricht                     Maastricht
#
#     berekende dichtheid
# 0                   252
# 1                   195
# 2                   188
# 3                   350
# 4                   300
# 5                   420
# 6                   912
# 7                  1081
# 8                  1374
# 9                   215
# 10                  522
# 11                  520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Vlag                            0 non-null      float64
#  1   Provincie                       12 non-null     string
#  2   Bevolking                       12 non-null     int64
#  3   Oppervlakte                     12 non-null     float64
#  4   Oppervlakte Land                12 non-null     float64
#  5   inwonersdichtheid               12 non-null     int64
#  6   Hoofdstad                       12 non-null     string
#  7   Gemeente met demeeste inwoners  12 non-null     string
#  8   berekende dichtheid             12 non-null     int64
# dtypes: float64(3), int64(3), string(3)
# memory usage: 992.0 bytes

# %%
df.describe()
# Out:
#        Vlag     Bevolking  Oppervlakte  Oppervlakte Land  inwonersdichtheid  \
# count   0.0  1.200000e+01    12.000000         12.000000          12.000000
# mean    NaN  1.450632e+06  3461.949167       2805.924167         527.416667
# std     NaN  1.107181e+06  1297.173728       1170.544359         389.059813
# min     NaN  3.834880e+05  1560.050000       1411.630000         188.000000
# 25%     NaN  5.628200e+05  2613.370000       2055.487500         242.750000
# 50%     NaN  1.139804e+06  3133.770000       2648.735000         385.000000
# 75%     NaN  2.205203e+06  4339.462500       3323.155000         619.500000
# max     NaN  3.708696e+06  5748.770000       4963.710000        1374.000000
#
#        berekende dichtheid
# count            12.000000
# mean            527.416667
# std             389.059813
# min             188.000000
# 25%             242.750000
# 50%             385.000000
# 75%             619.500000
# max            1374.000000

# %%
df.set_index(['Provincie','Hoofdstad'])
# Out:
#                                       Vlag  Bevolking  Oppervlakte  \
# Provincie           Hoofdstad
# Groningen           Groningen          NaN     585866      2959.68
# Friesland (Fryslân) Leeuwarden         NaN     649957      5748.77
# Drenthe             Assen              NaN     493682      2680.39
# Overijssel          Zwolle             NaN    1162406      3420.74
# Flevoland           Lelystad           NaN     423021      2412.31
# Gelderland          Arnhem             NaN    2085952      5136.31
# Utrecht             Utrecht            NaN    1354834      1560.05
# Noord-Holland       Haarlem            NaN    2879527      4091.93
# Zuid-Holland        Den Haag           NaN    3708696      3307.86
# Zeeland             Middelburg         NaN     383488      2933.44
# Noord-Brabant       's-Hertogenbosch   NaN    2562955      5082.06
# Limburg             Maastricht         NaN    1117201      2209.85
#
#                                       Oppervlakte Land  inwonersdichtheid  \
# Provincie           Hoofdstad
# Groningen           Groningen                  2323.94                252
# Friesland (Fryslân) Leeuwarden                 3335.62                195
# Drenthe             Assen                      2632.65                188
# Overijssel          Zwolle                     3319.00                350
# Flevoland           Lelystad                   1411.63                300
# Gelderland          Arnhem                     4963.71                420
# Utrecht             Utrecht                    1485.46                912
# Noord-Holland       Haarlem                    2664.82               1081
# Zuid-Holland        Den Haag                   2700.07               1374
# Zeeland             Middelburg                 1782.12                215
# Noord-Brabant       's-Hertogenbosch           4905.46                522
# Limburg             Maastricht                 2146.61                520
#
#                                      Gemeente met demeeste inwoners  \
# Provincie           Hoofdstad
# Groningen           Groningen                             Groningen
# Friesland (Fryslân) Leeuwarden                           Leeuwarden
# Drenthe             Assen                                     Emmen
# Overijssel          Zwolle                                 Enschede
# Flevoland           Lelystad                                 Almere
# Gelderland          Arnhem                                 Nijmegen
# Utrecht             Utrecht                                 Utrecht
# Noord-Holland       Haarlem                               Amsterdam
# Zuid-Holland        Den Haag                              Rotterdam
# Zeeland             Middelburg                            Terneuzen
# Noord-Brabant       's-Hertogenbosch                      Eindhoven
# Limburg             Maastricht                           Maastricht
#
#                                       berekende dichtheid
# Provincie           Hoofdstad
# Groningen           Groningen                         252
# Friesland (Fryslân) Leeuwarden                        195
# Drenthe             Assen                             188
# Overijssel          Zwolle                            350
# Flevoland           Lelystad                          300
# Gelderland          Arnhem                            420
# Utrecht             Utrecht                           912
# Noord-Holland       Haarlem                          1081
# Zuid-Holland        Den Haag                         1374
# Zeeland             Middelburg                        215
# Noord-Brabant       's-Hertogenbosch                  522
# Limburg             Maastricht                        520

# %%
df['inwonersdichtheid'].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df['inwonersdichtheid'].describe()
# Out:
# count      12.000000
# mean      527.416667
# std       389.059813
# min       188.000000
# 25%       242.750000
# 50%       385.000000
# 75%       619.500000
# max      1374.000000
# Name: inwonersdichtheid, dtype: float64

# %%
Q1 = df['inwonersdichtheid'].quantile(0.25)
Q3 = df['inwonersdichtheid'].quantile(0.75)

Q1, Q3

IQR = Q3 - Q1

top = Q3 + 1.5 * IQR
bottom = Q1 - 1.5 * IQR

# %%
top, bottom
# Out:
# (1184.625, -322.375)

# %%
df[((df['inwonersdichtheid'] < bottom) | (df['inwonersdichtheid'] > top))]
# Out:
#    Vlag     Provincie  Bevolking  Oppervlakte  Oppervlakte Land  \
# 8   NaN  Zuid-Holland    3708696      3307.86           2700.07
#
#    inwonersdichtheid Hoofdstad Gemeente met demeeste inwoners  \
# 8               1374  Den Haag                      Rotterdam
#
#    berekende dichtheid
# 8                 1374

# %%
df[df['Provincie'].str.match('Z.*d')]
# Out:
#    Vlag     Provincie  Bevolking  Oppervlakte  Oppervlakte Land  \
# 8   NaN  Zuid-Holland    3708696      3307.86           2700.07
# 9   NaN       Zeeland     383488      2933.44           1782.12
#
#    inwonersdichtheid   Hoofdstad Gemeente met demeeste inwoners  \
# 8               1374    Den Haag                      Rotterdam
# 9                215  Middelburg                      Terneuzen
#
#    berekende dichtheid
# 8                 1374
# 9                  215

# %%
naam.upper()
# Out:
# 'PETER'

# %%
df
# Out:
#     Vlag            Provincie  Bevolking  Oppervlakte  Oppervlakte Land  \
# 0    NaN            Groningen     585866      2959.68           2323.94
# 1    NaN  Friesland (Fryslân)     649957      5748.77           3335.62
# 2    NaN              Drenthe     493682      2680.39           2632.65
# 3    NaN           Overijssel    1162406      3420.74           3319.00
# 4    NaN            Flevoland     423021      2412.31           1411.63
# 5    NaN           Gelderland    2085952      5136.31           4963.71
# 6    NaN              Utrecht    1354834      1560.05           1485.46
# 7    NaN        Noord-Holland    2879527      4091.93           2664.82
# 8    NaN         Zuid-Holland    3708696      3307.86           2700.07
# 9    NaN              Zeeland     383488      2933.44           1782.12
# 10   NaN        Noord-Brabant    2562955      5082.06           4905.46
# 11   NaN              Limburg    1117201      2209.85           2146.61
#
#     inwonersdichtheid         Hoofdstad Gemeente met demeeste inwoners  \
# 0                 252         Groningen                      Groningen
# 1                 195        Leeuwarden                     Leeuwarden
# 2                 188             Assen                          Emmen
# 3                 350            Zwolle                       Enschede
# 4                 300          Lelystad                         Almere
# 5                 420            Arnhem                       Nijmegen
# 6                 912           Utrecht                        Utrecht
# 7                1081           Haarlem                      Amsterdam
# 8                1374          Den Haag                      Rotterdam
# 9                 215        Middelburg                      Terneuzen
# 10                522  's-Hertogenbosch                      Eindhoven
# 11                520        Maastricht                     Maastricht
#
#     berekende dichtheid
# 0                   252
# 1                   195
# 2                   188
# 3                   350
# 4                   300
# 5                   420
# 6                   912
# 7                  1081
# 8                  1374
# 9                   215
# 10                  522
# 11                  520

# %%
afkortingen = {'Groningen':'Gr',
 'Friesland (Fryslân)':'Fr',
 'Drenthe':'Dr',
 'Overijssel':'Ov',
 'Flevoland':'Fl',
 'Gelderland':'Ge',
 'Utrecht':'Ut',
 'Noord-Holland':'NH',
 'Zuid-Holland':'ZH',
 'Zeeland':'Ze',
 'Noord-Brabant':'NB',
 'Limburg':'Li'}
# Out:
# ['Groningen',
#  'Friesland (Fryslân)',
#  'Drenthe',
#  'Overijssel',
#  'Flevoland',
#  'Gelderland',
#  'Utrecht',
#  'Noord-Holland',
#  'Zuid-Holland',
#  'Zeeland',
#  'Noord-Brabant',
#  'Limburg']
