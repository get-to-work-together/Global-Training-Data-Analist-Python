# %%
import pandas as pd

# %%
pd.read_csv?

# %%
# !ls
# Out:
# Demo API.ipynb            Demo datastructuren.ipynb ca-500.csv
# Demo data inlezen.ipynb   Eerste notebook.ipynb     demo read_html.ipynb

# %% [markdown]
# ## CSV bestand inlezen in Pandas

# %%
filename = 'ca-500.csv'
df = pd.read_csv(filename, sep=';')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(10)
# Out:
#   first_name      last_name                 company_name  \
# 0  Francoise  Rautenstrauch            Riebesell, H F Jr
# 1     Kendra           Loud            Deloitte & Touche
# 2    Lourdes       Bauswell            Oklahoma Neon Inc
# 3     Hannah        Edmison           M B A Paint Stores
# 4        Tom          Loeza    Sheraton Shreveport Hotel
# 5    Queenie     Kramarczyk     Goeman Wood Products Inc
# 6        Hui        Portaro  A Storage Inn Of Gloucester
# 7     Josefa          Opitz            Norman Gale Isuzu
# 8        Lea      Steinhaus       James, Christopher Esq
# 9      Paola         Vielma               Congress Title
#
#                   address           city province   postal        phone1  \
# 0      2335 Canton Hwy #6        Windsor       ON  N8N 3N2  519-569-8399
# 1         6 Arch St #9757         Alcida       NB  E8J 2C4  506-363-1526
# 2     9547 Belmont Rd #21     Belleville       ON  K8P 1B3  613-903-7043
# ...

# %% [markdown]
# ## EDA - Exploratory Data Analysis

# %%
list(df.columns)
# Out:
# ['first_name',
#  'last_name',
#  'company_name',
#  'address',
#  'city',
#  'province',
#  'postal',
#  'phone1',
#  'phone2',
#  'email',
#  'web']

# %%
len(df.columns)
# Out:
# 11

# %%
df.dtypes
# Out:
# first_name      object
# last_name       object
# company_name    object
# address         object
# city            object
# province        object
# postal          object
# phone1          object
# phone2          object
# email           object
# web             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    500 non-null    object
#  1   last_name     500 non-null    object
#  2   company_name  500 non-null    object
#  3   address       500 non-null    object
#  4   city          500 non-null    object
#  5   province      500 non-null    object
#  6   postal        500 non-null    object
#  7   phone1        500 non-null    object
#  8   phone2        500 non-null    object
#  9   email         500 non-null    object
#  10  web           500 non-null    object
# dtypes: object(11)
# memory usage: 43.1+ KB

# %%
df[['company_name','city']]
# Out:
#                        company_name            city
# 0                 Riebesell, H F Jr         Windsor
# 1                 Deloitte & Touche          Alcida
# 2                 Oklahoma Neon Inc      Belleville
# 3                M B A Paint Stores       Vancouver
# 4         Sheraton Shreveport Hotel     LIle-Perrot
# ..                              ...             ...
# 495             Curtiss Wright Corp       Longueuil
# 496        Phelps Tool & Die Co Inc         Nanaimo
# 497         Factory Mattress Outlet          Quebec
# 498  Cosgroves N End Plbg & Hdwr Co       Beresford
# 499      Mission Lincoln Properties  Port Coquitlam
#
# [500 rows x 2 columns]

# %%
df[['company_name','city']].value_counts()
# Out:
# company_name                   city
# A & H Sptc Systems & Matl Inc  Vancouver         1
# Mission Lincoln Properties     Port Coquitlam    1
# Nabisco Inc                    Espanola          1
# N Amercn Min & Quar Equip Inc  Big Ridge         1
# Muscle Bound Bindery           Concord           1
#                                                 ..
# Euorpean Pretzel Bakery        Charlottetown     1
# Environmental Data Resources   Anjou             1
# Engravers                      Gatineau          1
# Emlou Boutique                 Quebec            1
# Young, Charles R Esq           Valley            1
# Length: 500, dtype: int64

# %%
df['province'].value_counts()
# Out:
# ON    175
# QC    116
# BC     72
# AB     42
# NB     30
# NS     23
# SK     21
# MB     12
# NL      8
# PE      1
# Name: province, dtype: int64

# %%
df['city'].value_counts()
# Out:
# Calgary            19
# Montreal           12
# Etobicoke          11
# Surrey              9
# Vancouver           9
#                    ..
# St Thomas           1
# Port Moody          1
# Greenfield Park     1
# Newmarket           1
# Port Coquitlam      1
# Name: city, Length: 227, dtype: int64

# %%
df['name'] = df['first_name'] + ' ' + df['last_name']

# %%
df.head(10)
# Out:
#   first_name      last_name                 company_name  \
# 0  Francoise  Rautenstrauch            Riebesell, H F Jr
# 1     Kendra           Loud            Deloitte & Touche
# 2    Lourdes       Bauswell            Oklahoma Neon Inc
# 3     Hannah        Edmison           M B A Paint Stores
# 4        Tom          Loeza    Sheraton Shreveport Hotel
# 5    Queenie     Kramarczyk     Goeman Wood Products Inc
# 6        Hui        Portaro  A Storage Inn Of Gloucester
# 7     Josefa          Opitz            Norman Gale Isuzu
# 8        Lea      Steinhaus       James, Christopher Esq
# 9      Paola         Vielma               Congress Title
#
#                   address           city province   postal        phone1  \
# 0      2335 Canton Hwy #6        Windsor       ON  N8N 3N2  519-569-8399
# 1         6 Arch St #9757         Alcida       NB  E8J 2C4  506-363-1526
# 2     9547 Belmont Rd #21     Belleville       ON  K8P 1B3  613-903-7043
# ...

# %%
df_names = df[['name','city']].copy()
df_names
# Out:
#                         name            city
# 0    Francoise Rautenstrauch         Windsor
# 1                Kendra Loud          Alcida
# 2           Lourdes Bauswell      Belleville
# 3             Hannah Edmison       Vancouver
# 4                  Tom Loeza     LIle-Perrot
# ..                       ...             ...
# 495           Erin Delbosque       Longueuil
# 496       Kassandra Marushia         Nanaimo
# 497           Leslee Matsuno          Quebec
# 498            Daniel Dobler       Beresford
# 499            Antonio Unruh  Port Coquitlam
#
# [500 rows x 2 columns]

# %%
df_names[ df_names['city'] == 'Montreal' ]
# Out:
#                      name      city
# 67          Mammie Cisney  Montreal
# 109           Tesha Brang  Montreal
# 233          Harris Sheck  Montreal
# 236         Maddie Foulds  Montreal
# 239      Steffanie Meinen  Montreal
# 315            Val Bigaud  Montreal
# 350          Denny Zeanah  Montreal
# 411          Luann Michon  Montreal
# 422          Verona Jobst  Montreal
# 424        Rikki Montalgo  Montreal
# 468           Ricki Traux  Montreal
# 483  Clemencia Momplaisir  Montreal

# %%
df_names[ df_names['city'] == 'Montreal' ]
# Out:
#                      name      city
# 67          Mammie Cisney  Montreal
# 109           Tesha Brang  Montreal
# 233          Harris Sheck  Montreal
# 236         Maddie Foulds  Montreal
# 239      Steffanie Meinen  Montreal
# 315            Val Bigaud  Montreal
# 350          Denny Zeanah  Montreal
# 411          Luann Michon  Montreal
# 422          Verona Jobst  Montreal
# 424        Rikki Montalgo  Montreal
# 468           Ricki Traux  Montreal
# 483  Clemencia Momplaisir  Montreal

# %%
df['city'].value_counts()
# Out:
# Calgary            19
# Montreal           12
# Etobicoke          11
# Surrey              9
# Vancouver           9
#                    ..
# St Thomas           1
# Port Moody          1
# Greenfield Park     1
# Newmarket           1
# Port Coquitlam      1
# Name: city, Length: 227, dtype: int64

# %%
df['province'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df['province'].value_counts().plot(kind = 'barh')
# Out:
# <AxesSubplot:>
